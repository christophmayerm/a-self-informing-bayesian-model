# %%
import pandas as pd
import numpy as np

from sklearn.decomposition import PCA

from matplotlib import pyplot as plt

# %%
df = pd.read_csv("../../benchmarks/data/harth_dataset_10000.csv")
df
# Out:
#         back_x    back_y    back_z   thigh_x   thigh_y   thigh_z
# 0    -0.685493  0.031255 -0.806762 -0.175290  0.228088  0.966205
# 1    -0.896097  0.058939 -0.446554 -0.326335  0.012409  0.948112
# 2    -0.875977 -0.315674 -0.219727 -0.715088 -0.220947 -0.151855
# 3    -0.531250  0.203125  0.640625  0.158447  0.228760 -1.042480
# 4    -0.903809  0.003662 -0.273438 -0.351074  0.038086 -0.455078
# ...        ...       ...       ...       ...       ...       ...
# 9995 -1.020432 -0.002741 -0.105917 -0.170505 -0.322992  1.003168
# 9996 -1.003303  0.058877  0.016675 -0.166383  0.117837  0.994695
# 9997 -1.040500  0.041754 -0.137792 -0.716414  0.083507 -0.047325
# 9998 -1.031329  0.015588 -0.139127 -0.286550  0.144259  0.948116
# 9999 -0.906494 -0.163574 -0.500000 -1.104736 -0.242432 -0.863281
#
# [10000 rows x 6 columns]

# %%
X = PCA(n_components=2).fit_transform(df.to_numpy())
X
# Out:
# array([[-0.83234466, -0.04645725],
#        [-0.65430831,  0.15073186],
#        [ 0.4916311 , -0.19981478],
#        ...,
#        [ 0.398706  , -0.06570208],
#        [-0.65117987,  0.18568231],
#        [ 1.26383967, -0.30952639]])

# %%
plt.figure(figsize=(16, 9))

plt.scatter(X[:, 0], X[:, 1])

plt.show()
